# %% [markdown]
# # Retention and functional breadth
# CPU-only analysis of existing four-vector results. Does not interrupt the GPU run or edit its files.

# %%
from pathlib import Path
from analyze_retention import run

SOURCE = Path("/home/ubuntu/4/runs/olmo_precise_forgetting_v1/runs/olmo_four_vector_v1")
OUTPUT = Path.cwd() / "retention_analysis"
# SOURCE may instead be the four_vector_share.zip file.
results = run(SOURCE, OUTPUT)
