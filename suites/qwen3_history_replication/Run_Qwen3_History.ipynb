# %% [markdown]
# # Qwen3: natural forgetting, history ages and finite paths
# Run in this extracted folder on the **new GH200**. No previous experiment files required. Workers run quietly in the separate environment. Refresh Status manually. Scientific defaults and limitations are in README.md.

# %% [markdown]
# ## 1. GPU environment — once
# Creates a separate environment and tests CUDA/Qwen3. Installation details go to setup.log. Keep the current notebook kernel.

# %%
from setup_gh200 import setup
GPU_PYTHON = setup()

# %% [markdown]
# ## 2. Configuration
# Defaults: three fresh seeds, paired shared/disjoint answers; 23.5 hours per launch, resumable. Reopening loads saved settings.

# %%
import json
from pathlib import Path
import replication as study
SETTINGS = study.defaults()
saved = Path(SETTINGS["output"]) / "settings.json"
if saved.exists():
    SETTINGS = json.loads(saved.read_text())
print("Output:", SETTINGS["output"])
print("Seeds:", SETTINGS["seeds"], "| hours per session:", SETTINGS["hours"])

# %% [markdown]
# ## 3. Launch / resume
# Automatically: natural trajectories → exact history replay → selected finite paths. Run again after a cooperative pause or session budget. A completed run is left unchanged.

# %%
study.launch(SETTINGS)

# %% [markdown]
# ## 4. Refresh status
# Rerun this cell whenever you want a progress check. Status does not run the experiment.

# %%
print(json.dumps(study.status(SETTINGS), indent=2))

# %% [markdown]
# ## 5. Numbers and plots — on demand

# %%
study.show_results(SETTINGS)

# %% [markdown]
# ## 6. Stop — only when wanted
# Set STOP_NOW=True and run. Wait for alive=False before resuming. Completed records remain saved.

# %%
STOP_NOW = False
if STOP_NOW:
    print(study.stop(SETTINGS))

# %% [markdown]
# ## 7. Export a share ZIP
# Safe database snapshots; excludes model checkpoints. Set EXPORT_NOW=True when needed.

# %%
EXPORT_NOW = False
if EXPORT_NOW:
    archive = study.export(SETTINGS)
    print(archive)
    from IPython.display import FileLink, display
    display(FileLink(str(Path(archive).relative_to(Path.cwd()))))
